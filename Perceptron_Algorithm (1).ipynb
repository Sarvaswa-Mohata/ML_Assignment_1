# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-fda3d832-4670-4641-a7ac-8852f13a7185" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fda3d832-4670-4641-a7ac-8852f13a7185">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd

class Perceptron:
    
    def __init__(self, learning_rate, epochs):
        self.weights = None
        self.bias = None
        self.learning_rate = learning_rate
        self.epochs = epochs

    # activation function
    def activation(self, z):
        return np.sign(z) 

    def fit(self, X, y):
        n_features = X.shape[1]
        
        # Initializing weights and bias
        self.weights = np.zeros((n_features))
        self.bias = 0
        
        # Iterating until the number of epochs
        for epoch in range(self.epochs):
            
            # Traversing through the entire training set
            for i in range(len(X)):
                z = np.dot(X, self.weights) + self.bias # Finding the dot product and adding the bias
                y_pred = self.activation(z) # Passing through an activation function
                
                #Updating weights and bias
                self.weights = self.weights + self.learning_rate * (y[i]) * X[i]
                self.bias = self.bias + self.learning_rate * (y[i])
                
        return self.weights, self.bias

    def predict(self, X):
        z = np.dot(X, self.weights) + self.bias
        return self.activation(z)

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['file_1.csv']))
diagnosis= [1 if i=='M' else -1 for i in df['diagnosis']]
df['diagnosis'] = diagnosis
df['diagnosis']=np.array(df['diagnosis'],dtype=np.float64)

# %%
df.fillna(0)
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302        1.0        17.99         10.38          122.80
# 1      842517        1.0        20.57         17.77          132.90
# 2    84300903        1.0        19.69         21.25          130.00
# 3    84348301        1.0        11.42         20.38           77.58
# 4    84358402        1.0        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424        1.0        21.56         22.39          142.00
# 565    926682        1.0        20.13         28.25          131.20
# 566    926954        1.0        16.60         28.08          108.30
# 567    927241        1.0        20.60         29.33          140.10
# 568     92751       -1.0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %%
# impute missing values for continuous feature with mean

mean_radius_mean = df['radius_mean'].mean()
df['radius_mean'] = df['radius_mean'].fillna(mean_radius_mean)

mean_texture_mean = df['texture_mean'].mean()
df['texture_mean'] = df['texture_mean'].fillna(mean_texture_mean)

mean_perimeter_mean = df['perimeter_mean'].mean()
df['perimeter_mean'] = df['perimeter_mean'].fillna(mean_perimeter_mean)

mean_area_mean = df['area_mean'].mean()
df['area_mean'] = df['area_mean'].fillna(mean_area_mean)

mean_smoothness_mean = df['smoothness_mean'].mean()
df['smoothness_mean'] = df['smoothness_mean'].fillna(mean_smoothness_mean)

mean_compactness_mean = df['compactness_mean'].mean()
df['compactness_mean'] = df['compactness_mean'].fillna(mean_compactness_mean)

mean_concavity_mean = df['concavity_mean'].mean()
df['concavity_mean'] = df['concavity_mean'].fillna(mean_concavity_mean)

mean_concave_points_mean = df['concave_points_mean'].mean()
df['concave_points_mean'] = df['concave_points_mean'].fillna(mean_concave_points_mean)

mean_symmetry_mean = df['symmetry_mean'].mean()
df['symmetry_mean'] = df['symmetry_mean'].fillna(mean_symmetry_mean)

mean_fractal_dimension_mean = df['fractal_dimension_mean'].mean()
df['fractal_dimension_mean'] = df['fractal_dimension_mean'].fillna(mean_fractal_dimension_mean)

mean_radius_se = df['radius_se'].mean()
df['radius_se'] = df['radius_se'].fillna(mean_radius_se)

mean_texture_se = df['texture_se'].mean()
df['texture_se'] = df['texture_se'].fillna(mean_texture_se)

mean_perimeter_se = df['perimeter_se'].mean()
df['perimeter_se'] = df['perimeter_se'].fillna(mean_perimeter_se)

mean_area_se = df['area_se'].mean()
df['area_se'] = df['area_se'].fillna(mean_area_se)

mean_smoothness_se = df['smoothness_se'].mean()
df['smoothness_se'] = df['smoothness_se'].fillna(mean_smoothness_se)

mean_compactness_se = df['compactness_se'].mean()
df['compactness_se'] = df['compactness_se'].fillna(mean_compactness_se)

mean_concavity_se = df['concavity_se'].mean()
df['concavity_se'] = df['concavity_se'].fillna(mean_concavity_se)

mean_concave_points_se = df['concave_points_se'].mean()
df['concave_points_se'] = df['concave_points_se'].fillna(mean_concave_points_se)

mean_symmetry_se = df['symmetry_se'].mean()
df['symmetry_se'] = df['symmetry_se'].fillna(mean_symmetry_se)

mean_fractal_dimension_se = df['fractal_dimension_se'].mean()
df['fractal_dimension_se'] = df['fractal_dimension_se'].fillna(mean_fractal_dimension_se)

mean_radius_worst = df['radius_worst'].mean()
df['radius_worst'] = df['radius_worst'].fillna(mean_radius_worst)

mean_texture_worst = df['texture_worst'].mean()
df['texture_worst'] = df['texture_worst'].fillna(mean_texture_worst)

mean_perimeter_worst = df['perimeter_worst'].mean()
df['perimeter_worst'] = df['perimeter_worst'].fillna(mean_perimeter_worst)

mean_area_worst = df['area_worst'].mean()
df['area_worst'] = df['area_worst'].fillna(mean_area_worst)

mean_smoothness_worst = df['smoothness_worst'].mean()
df['smoothness_worst'] = df['smoothness_worst'].fillna(mean_smoothness_worst)

mean_compactness_worst = df['compactness_worst'].mean()
df['compactness_worst'] = df['compactness_worst'].fillna(mean_compactness_worst)

mean_concavity_worst = df['concavity_worst'].mean()
df['concavity_worst'] = df['concavity_worst'].fillna(mean_concavity_worst)

mean_concave_points_worst = df['concave_points_worst'].mean()
df['concave_points_worst'] = df['concave_points_worst'].fillna(mean_concave_points_worst)

mean_symmetry_worst = df['symmetry_worst'].mean()
df['symmetry_worst'] = df['symmetry_worst'].fillna(mean_symmetry_worst)

mean_fractal_dimension_worst = df['fractal_dimension_worst'].mean()
df['fractal_dimension_worst'] = df['fractal_dimension_worst'].fillna(mean_fractal_dimension_worst)

df
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302        1.0        17.99         10.38          122.80
# 1      842517        1.0        20.57         17.77          132.90
# 2    84300903        1.0        19.69         21.25          130.00
# 3    84348301        1.0        11.42         20.38           77.58
# 4    84358402        1.0        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424        1.0        21.56         22.39          142.00
# 565    926682        1.0        20.13         28.25          131.20
# 566    926954        1.0        16.60         28.08          108.30
# 567    927241        1.0        20.60         29.33          140.10
# 568     92751       -1.0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %%
# Python program to define a function to compute accuracy score of model's predicted class  
  
# Defining a function which takes true values of the sample and values predicted by the model  
def compute_accuracy(Y_true, Y_pred):  
    correctly_predicted = 0  
    # iterating over every label and checking it with the true sample  
    from sklearn.metrics import accuracy_score
    for true_label, predicted in zip(Y_true, Y_pred):  
        if true_label == predicted:  
            correctly_predicted += 1  
    # computing the accuracy score  
    accuracy_score = correctly_predicted / len(Y_true)

# %%
# split the data into training and testing sets
from sklearn.model_selection import train_test_split
def train_test_split(data, test_ratio=0.33, random_state=22):
    if random_state is not None:
        np.random.seed(random_state)
    # split the data into training and testing sets
    split_idx = int(len(data) * (1 - test_ratio))
    shuffled_idx = np.random.permutation(len(data))
    train_idx = shuffled_idx[:split_idx]
    test_idx = shuffled_idx[split_idx:]    
    train_data = data[train_idx]
    test_data = data[test_idx]
    
    return train_test_split(x, y, test_size=0.33, random_state=22)

# split the data into training and testing sets
x=df.loc[:, df.columns != 'diagnosis']
y=df.loc[:, df.columns == 'diagnosis']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=29)

# %%
x_train=np.array(x_train,dtype=np.float64)
y_train=np.array(y_train,dtype=np.float64)
perceptron = Perceptron(0.001, 1000)
perceptron.fit(x_train, y_train)

pred = perceptron.predict(x_test)
from sklearn.metrics import accuracy_score
accuracy_score(pred, y_test)
# Out:
# 0.5957446808510638

# %%
normalized_x = (x-x.mean())/x.std()

# %%
x = normalized_x
# x = df.loc[: , df.columns != 'diagnosis']
# y=df.loc[:, df.columns == 'diagnosis']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=29)

x_train=np.array(x_train,dtype=np.float64)
y_train=np.array(y_train,dtype=np.float64)
perceptron = Perceptron(0.001, 1000)
perceptron.fit(x_train, y_train)

pred = perceptron.predict(x_test)
from sklearn.metrics import accuracy_score
accuracy_score(pred, y_test)
# Out:
# 0.925531914893617

# %%
df=df.sample(frac=1, axis=1).sample(frac=1).reset_index(drop=True)
x=df.loc[:, df.columns != 'diagnosis']
y=df.loc[:, df.columns == 'diagnosis']
#x = (x-x.mean())/x.std()
df
# Out:
#      perimeter_se  fractal_dimension_mean  concavity_se  diagnosis  \
# 0           1.539                 0.05781       0.01498       -1.0
# 1           1.553                 0.07818       0.00000       -1.0
# 2           1.391                 0.06344       0.01652       -1.0
# 3           1.848                 0.06043       0.02322       -1.0
# 4           3.705                 0.06487       0.04252        1.0
# ..            ...                     ...           ...        ...
# 564         2.217                 0.07613       0.03672        1.0
# 565         1.592                 0.05594       0.02828       -1.0
# 566         1.516                 0.06104       0.02941       -1.0
# 567         4.106                 0.05223       0.01946        1.0
# 568         3.591                 0.06672       0.05551        1.0
#
#      radius_mean  smoothness_worst  symmetry_mean  concave_points_se  \
# 0         13.210            0.1072         0.1628           0.009117
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=29)

# %%
x_train=np.array(x_train,dtype=np.float64)
y_train=np.array(y_train,dtype=np.float64)
perceptron = Perceptron(0.001, 1000)
perceptron.fit(x_train, y_train)

pred = perceptron.predict(x_test)

accuracy_score(pred, y_test)
# Out:
# 0.6595744680851063

# %%
df = df.sample(frac = 1)
x=df.loc[:, df.columns != 'diagnosis']
y=df.loc[:, df.columns == 'diagnosis']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=22)

x_train=np.array(x_train,dtype=np.float64)
y_train=np.array(y_train,dtype=np.float64)
perceptron = Perceptron(0.001, 1000)
perceptron.fit(x_train, y_train)

pred = perceptron.predict(x_test)

accuracy_score(pred, y_test)
# Out:
# 0.6382978723404256
